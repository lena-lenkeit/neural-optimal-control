# %%
import jax
import jax.numpy as jnp

jax.config.update("jax_platform_name", "cpu")
jax.config.update("jax_enable_x64", True)

from functools import partial
from typing import Callable, Tuple

import diffrax
import matplotlib.pyplot as plt
from jaxtyping import Array, ArrayLike, PRNGKeyArray, Scalar

# %% [markdown]
# # Generator for tissue sections

# %%
def make_tissue_section(grid_size: Tuple[int]):
    ...


def normal_pdf(x: Array, mean: Array, std: Array, normalize: bool = True) -> Array:
    density = jnp.exp(-0.5 * ((x - mean) / std) ** 2)

    if normalize:
        factor = 1 / (std * jnp.sqrt(2 * jnp.pi))
        density = factor * density

    return density


def dot(v1: Array, v2: Array, axis: int = -1, keepdims: bool = False) -> Array:
    return jnp.sum(v1 * v2, axis=axis, keepdims=keepdims)


def project(v1: Array, v2: Array, axis: int = -1) -> Array:
    """Projects vector v1 onto vector v2"""

    return v2 * dot(v1, v2, axis=axis, keepdims=True)


def normalize(vector: Array, axis: int = -1) -> Array:
    return vector / jnp.linalg.norm(vector, ord=2, axis=axis, keepdims=True)


def distance_to_line(
    query: Array, origin: Array, direction: Array, axis: int = -1
) -> Array:
    offset = query - origin
    projected = offset - project(offset, direction, axis=axis)
    distance = jnp.linalg.norm(projected, ord=2, axis=axis)

    return distance


def make_capillaries(
    grid_size: Tuple[int], num_capillaries: int, key: PRNGKeyArray
) -> Array:
    key, origin_key, direction_key = jax.random.split(key, num=3)
    origins = jax.random.uniform(origin_key, (num_capillaries, 2))
    directions = jax.random.normal(direction_key, (num_capillaries, 2))
    directions = normalize(directions)

    grid_pos_x = jnp.linspace(0.0, 1.0, num=grid_size[0], endpoint=False)
    grid_pos_y = jnp.linspace(0.0, 1.0, num=grid_size[1], endpoint=False)

    grid_pos_x = grid_pos_x + 0.5 / grid_size[0]
    grid_pos_y = grid_pos_y + 0.5 / grid_size[1]

    grid_pos_xy = jnp.stack(jnp.meshgrid(grid_pos_x, grid_pos_y), axis=-1).reshape(
        grid_size[1] * grid_size[0], 2
    )

    capillary_distances = jax.vmap(distance_to_line, in_axes=(None, 0, 0), out_axes=0)(
        grid_pos_xy, origins, directions
    )

    return capillary_distances

# %%
key = jax.random.PRNGKey(15)
capillary_distances = make_capillaries((16, 16), 4, key)
capillary_densities = jnp.sum(
    normal_pdf(capillary_distances, jnp.zeros(1), jnp.full(1, 0.025), normalize=False),
    axis=0,
)
capillary_masks = (capillary_densities > .2).astype(jnp.float_)
capillary_smooth_masks = jnp.clip(capillary_densities, a_max=1.0)

plt.figure()
#plt.imshow(capillary_masks.reshape(16, 16))
plt.imshow(jnp.min(capillary_distances, axis=0).reshape(16, 16))
plt.show()

# %% [markdown]
# # ODE

# %%
def reaction_diffusion_ode(
    t: ArrayLike, y: Array, args: Tuple[Callable, Callable, int, int, Array]
) -> Array:
    reaction_ode, diffusion_ode, n, m, capillaries = args

    reaction_dy = jax.vmap(reaction_ode, in_axes=(0, None, 0), out_axes=0)(
        y.reshape(n * m, 4), jnp.zeros(2), capillaries
    ).reshape(n, m, 4)
    diffusion_dy = diffusion_ode(y)

    return reaction_dy + diffusion_dy


def diffusion_ode(y: Array) -> Array:
    # Derive kernel via finite-differences

    # Get distances from center element
    kernel_x = jnp.linspace(-1, 1, 3).reshape(1, -1).repeat(3, axis=0)
    kernel_y = jnp.linspace(-1, 1, 3).reshape(-1, 1).repeat(3, axis=1)
    kernel_d = -1 / jnp.sqrt(jnp.square(kernel_x) + jnp.square(kernel_y))
    kernel_d = kernel_d.at[1, 1].set(0)

    # Center element has weight equal to the sum of all other elements
    kernel_s = jnp.sum(kernel_d)
    kernel = kernel_d.at[1, 1].set(-kernel_s)

    # Convolve reaction area with diffusion kernel
    #d = jnp.asarray([0.01, 0.1, 1.0, 1.0]) * 0.1
    d = jnp.asarray([0.0, 0.01, 1.0, 1.0])
    y = jax.vmap(
        partial(jnp.pad, pad_width=((1, 1), (1, 1)), mode="edge"),
        in_axes=-1,
        out_axes=-1,
    )(y)
    j = -d * jax.vmap(
        partial(jax.scipy.signal.convolve, mode="valid"),
        in_axes=(-1, None),
        out_axes=-1,
    )(y, kernel)

    return j


def fibrosis_ode(y: Array, u: Array, capillaries: Array) -> Array:
    k = [None] * 14

    k[0] = 0.9  # proliferation rates: lambda1=0.9/day,
    k[1] = 0.8  # lambda2=0.8/day
    k[2] = 0.3  # mu_1, mu_2, death rates: 0.3/day
    k[3] = 1e6  # carrying capacity: 10^6 cells
    k[4] = 2  # growth factor degradation: gamma=2/day
    k[5] = (
        240 * 1440
    )  # growth factor secretion rates: beta3=240 molecules/cell/min  ---- beta_3
    k[6] = (
        470 * 1440
    )  # beta1=470 molecules/cell/min                                ---- beta_1
    k[7] = (
        70 * 1440
    )  # beta2=70 molecules/cell/min                                 ---- beta_2
    k[8] = (
        940 * 1440
    )  # alpha1=940 molecules/cell/min, endocytosis rate CSF1       ---- alpha_1
    k[9] = (
        510 * 1440
    )  # alpha2=510 molecules/cell/min, endocytosis rate PDGF     ---- alpha_2
    k[10] = 6e8  # #binding affinities: k1=6x10^8 molecules (PDGF)     ---- k_1
    k[11] = 6e8  # k2=6x10^8 (CSF)                                   ---- k_2
    k[12] = 0.0  # 120 inflammation pulse
    k[13] = 1e6

    ## Control
    # PDGF antibody
    k_pdgf_ab = 1 * 1440  # 1 / (min * molecule)
    pdgf_ab_deg = -k_pdgf_ab * y[3] * u[0]

    # CSF1 antibody
    k_csf1_ab = 1 * 1440  # 1 / (min * molecule)
    csf1_ab_deg = -k_csf1_ab * y[2] * u[1]

    ## Capillaries
    k_pdgf_diffusion = 100 * 1440  # 1 / min
    k_csf1_diffusion = 100 * 1440  # 1 / min

    pdgf_capillary_diffusion = -k_pdgf_diffusion * y[3] * capillaries
    csf1_capillary_diffusion = -k_csf1_diffusion * y[2] * capillaries

    dy = [None] * 4

    dy[0] = y[0] * (
        k[0] * y[3] / (k[10] + y[3]) * (1 - y[0] / k[3]) - k[2]
    )  # Fibrobasts
    dy[1] = y[1] * (k[1] * y[2] / (k[11] + y[2]) - k[2]) + k[12]  # Mph
    dy[2] = (
        csf1_ab_deg
        + csf1_capillary_diffusion
        + k[6] * y[0]
        - k[8] * y[1] * y[2] / (k[11] + y[2])
        - k[4] * y[2]
    )  # CSF
    dy[3] = (
        pdgf_ab_deg
        + pdgf_capillary_diffusion
        + k[7] * y[1]
        + k[5] * y[0]
        - k[9] * y[0] * y[3] / (k[10] + y[3])
        - k[4] * y[3]
    )  # PDGF

    return jnp.stack(dy, axis=-1)


def zero_ode(y: Array, u: Array) -> Array:
    return jnp.zeros_like(y)

# %%
y0 = jnp.ones((16, 16, 4))
y0 = y0.at[8, 10, 1].set(1e8)

sol = diffrax.diffeqsolve(
    terms=diffrax.ODETerm(reaction_diffusion_ode),
    solver=diffrax.Kvaerno5(),
    t0=0.0,
    t1=100.0,
    dt0=0.1,
    y0=y0,
    args=(fibrosis_ode, diffusion_ode, 16, 16, capillary_masks),
    saveat=diffrax.SaveAt(dense=True),
    stepsize_controller=diffrax.PIDController(
        rtol=1e-5, atol=1e-5, pcoeff=0.3, icoeff=0.3
    ),
    max_steps=100000,
)

# %%
sol.evaluate(100.0)[8, 8]

# %%
plt.figure()
plt.yscale("log")
plt.plot(jax.vmap(sol.evaluate)(jnp.linspace(0.0, 100.0, 1024))[:, 8, 10])
plt.show()

# %%
plt.figure()
plt.imshow(sol.evaluate(100.0)[..., 1], vmin=0, vmax=1e5)
plt.show()

# %%
sol.stats
